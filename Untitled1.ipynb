# %% [markdown]
# # Trigonometrische Funktionen
# Die Graphen der Sinus- und Kosinusfunktion können auf verschiedene Weise verändert werden. Sie können in 𝑥− und 𝑦− Richtung verschoben, gestreckt oder gestaucht sein.
#
# Eine veränderte trigonometrische Funktion kann zum Beispiel so aussehen: 𝑓(𝑥)=3⋅𝑠𝑖𝑛(2⋅𝑥+1)−1.
#
# Um die Veränderungen leichter beschreiben zu können, klammert man den Faktor vor dem 𝑥 aus: 𝑓(𝑥)=3⋅𝑠𝑖𝑛(2⋅(𝑥+12))−1.
#
# Allgemeine Form
# Sinus: f(x) = a ⋅ sin (b ⋅ (x + c)) + d
# Kosinus: f(x) = a ⋅ cos (b ⋅ (x + c)) + d
# Tangent: f(x) = a ⋅ tan(b ⋅ (x + c)) + d
# Die reellen Parameter 𝑎,𝑏,𝑐,𝑑 bestimmen, wie der Graph genau verändert wird.
#
# Bemerkung: Nicht nur trigonometrische Funktionen lassen sich so verändern. Unter den folgenden Links findest du wie man den Graphen einer beliebigen Funktion verschiebt oder staucht, oder streckt.
#
# Einfluss der Parameter auf den Funktionsgraphen
# Beobachtung an Beispielen

# %% [markdown]
# ### 1. Betrachte f(x) = sin (2 ⋅ x) + 1.

# %%
# %matplotlib inline  
import numpy as np
import sympy as sp
import math as m
import matplotlib.pyplot as plt
import ipywidgets as widgets

from ipywidgets import interact
from sympy import symbols
from sympy.plotting import plot3d
from matplotlib.pyplot import figure

# %%
x = np.arange(0,3*np.pi,0.1)   # start,stop,step
y = np.sin(2*x) + 1
z = np.sin(x)

# %%
    plt.plot(x,y,x,z)
    plt.xlabel('x values from 0 to 2π')  # string must be enclosed with quotes '  '
    plt.ylabel('sin(2x) + 1 and sin(x)')
    plt.title('Plot of sin(x) and sin(2x) + 1 from 0 to 2π')
    plt.legend(['sin(2x) + 1', 'sin(x)'])      # legend entries as seperate strings in a list
    plt.show()

# %% [markdown]
# Der Funktionsgraph verändert sisch unter dem Einfluss der Parameter d und b:
#
# 1. Zunächst wird d vom Startwert  0  beginnend bis zum Endwert  1  verändert. Währenddessen verschiebt sich der Funktionsgraph um  1  in  𝑦−𝑅𝑖𝑐ℎ𝑡𝑢𝑛𝑔  nach oben. Beim Endwert d=1 hat die Funktion die Ruhelage  𝑦=1 .
#
# ⇒𝑑  verändert also die Ruhelage der Funktion.
#
# 2. Danach wird b vom Startwert  1  beginnend bis zum Endwert  2  verändert. Währenddessen staucht sich der Funktionsgraph in  𝑥−𝑅𝑖𝑐ℎ𝑡𝑢𝑛𝑔  zusammen; die Wellenberge und Wellentäler rücken enger aneinander, die Periode der Funktion wird kleiner. Beim Endwert  𝑏=2  ist die Periode nur noch  π  statt  2π .  ⇒𝑏  verändert also die Periode der Funktion.

# %% [markdown]
# ### 2. Betrachte g(x) = 2 ⋅ cos(x − 1).

# %%
x = np.arange(0,3*np.pi,0.1)   # start,stop,step
y = np.cos(x-1)*2
z = np.cos(x)

plt.plot(x,y,x,z)
plt.xlabel('x values from 0 to 2π')  # string must be enclosed with quotes '  '
plt.ylabel('2*cos(x-1) and cos(x)')
plt.title('Plot of cos(x) and 2cos(x-1) from 0 to 2π')
plt.legend(['2cos(x-1)', 'cos(x)'])      # legend entries as seperate strings in a list
plt.show()

# %% [markdown]
# Der Funktionsgraph verändert sisch unter dem Einfluss der Parameter a und c:
#
# 1.   Zuerst wird  𝑐  vom Startwert  0  beginnend auf den Wert  −1  verändert. Dabei verschiebt sich der Funktionsgraph in  𝑥−𝑅𝑖𝑐ℎ𝑡𝑢𝑛𝑔  um den Wert  1  nach rechts.
#
# ⇒  𝑐  verändert also die Lage des Funktionsgraphen in  𝑥−𝑅𝑖𝑐ℎ𝑡𝑢𝑛𝑔 .
#
# 2.   Danach wird  𝑎  vom Startwert  1  beginnend bis zum Endwert  2  verändert. Dabei wird der Funktionsgraph in  𝑦−𝑅𝑖𝑐ℎ𝑡𝑢𝑛𝑔  gestreckt.
#
# ⇒  𝑎  verändert also die Amplitude der Funktion.

# %% [markdown]
# ### Überblick über den Einfluss der Parameter
#
# ### Parameter a

# %% [markdown]
# Der Parameter a beeinflusst die Amplitude. Er streckt/staucht den Graph in y-Richtung.
#
# Der Graph hat die Amplitude |a|
# a < 0: Der Graph wird zusätzlich an der Ruhelage gespiegelt.

# %%
x = np.arange(0,3*np.pi,0.1)   # start,stop,step
y = np.sin(x)/(-2)
z = np.sin(x)
p = np.sin(x)*3

plt.plot(x,y,x,z,x,p)
plt.xlabel('x values from 0 to 2π')  # string must be enclosed with quotes '  '
plt.ylabel('- 0,5 * sin(x), sin(x) and 3 * sin(x)')
plt.title('Plot of - 0,5 * sin(x), sin(x) and 3 * sin(x) from 0 to 2π')
plt.legend(['- 0,5*sin(x)', 'sin(x)','3*sin(x)'])      # legend entries as seperate strings in a list
plt.show()

# %%
from ipywidgets import interact, interactive, fixed, interact_manual
import ipywidgets as widgets

import matplotlib.pyplot as plt
# %matplotlib inline

import numpy as np

def plot_func (a):
   # x = np.linspace(0, 2*np.pi,)
    x = np.arange(0,3*np.pi,0.05)
    y = np.sin(x)/(-a)
    z = np.sin(x)
    p = np.sin(x)*a
    
    plt.plot(x, y,x,z,x,p)
    plt.grid()
    plt.xlabel('x values from 0 to 2π')  # string must be enclosed with quotes '  '
    plt.ylabel('- a * sin(x), sin(x) and a * sin(x)')
    plt.title('Plot of - a * sin(x), sin(x) and a * sin(x) from 0 to 2π')
    plt.legend(['- a*sin(x)', 'sin(x)','a*sin(x)'])      # legend entries as seperate strings in a list

interact(plot_func, a = widgets.FloatSlider(value=7.5,min=0.1, max=10.0, step=0.5))
# Out:
# interactive(children=(FloatSlider(value=7.5, description='a', max=10.0, min=0.1, step=0.5), Output()), _dom_cl…
# <function __main__.plot_func(a)>

# %%
Res1 = plot_func(a)
Res1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-34c1129471e5> in <module>
# ----> 1 Res1 = plot_func(a)
#       2 Res1
#
# NameError: name 'a' is not defined

# %%
caption = widgets.Label(value='The values of range1 and Res1 are synchronized')
range1, a = widgets.IntSlider(description='Range 1'),\
                 widgets.IntSlider(description='a')
l = widgets.jslink((range1, 'value'), (a, 'value'))
display(caption, range1, a)
# Out:
# Label(value='The values of range1 and Res1 are synchronized')
# IntSlider(value=0, description='Range 1')
# IntSlider(value=0, description='a')

# %% [markdown]
# ### Parameter b
#
# Der Parameter b beeinflusst die Periode. Er streckt/staucht den Graph in  𝑥−𝑅𝑖𝑐ℎ𝑡𝑢𝑛𝑔 .
#
# Der Graph hat die Periode p = 2π / |b|
#
# b<0: Der Graph wird zusätzlich an der senkrechten Achse x = − c gespiegelt

# %%
x = np.arange(0,3*np.pi,0.1)   # start,stop,step
y = np.sin(-2*x)
z = np.sin(x)
p = np.sin(2*x)

plt.plot(x,y,x,z,x,p)
plt.xlabel('x values from 0 to 2π')  # string must be enclosed with quotes '  '
plt.ylabel('sin(-2x), sin(x) and sin(2x)')
plt.title('Plot of sin(-2x), sin(x) and sin(2x) from 0 to 2π')
plt.legend(['sin(-2x)', 'sin(x)','sin(2x)'])      # legend entries as seperate strings in a list
plt.show()

# %%
def plot_func(b):
   # x = np.linspace(0, 2*np.pi,)
    x = np.arange(0,3*np.pi,0.05)
    y = np.sin(-b*x)
    z = np.sin(x)
    p = np.sin(b*x)
    
    plt.plot(x, y,x,z,x,p)
    plt.grid()
    plt.xlabel('x values from 0 to 2π')  # string must be enclosed with quotes '  '
    plt.ylabel('sin(-bx), sin(x) and sin(bx)')
    plt.title('Plot of sin(-bx), sin(x) and sin(bx) from 0 to 2π')
    plt.legend(['sin(-bx)', 'sin(x)','sin(bx)'])      # legend entries as seperate strings in a list

interact(plot_func, b = widgets.FloatSlider(value=7.5,min=0.01, max=2.0, step=0.1))
# Out:
# interactive(children=(FloatSlider(value=2.0, description='b', max=2.0, min=0.01), Output()), _dom_classes=('wi…
# <function __main__.plot_func(b)>

# %%
widgets.jslink((a, 'value'), (b, 'value'))
display(a)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-56e7f8476e88> in <module>
# ----> 1 widgets.jslink((a, 'value'), (b, 'value'))
#       2 display(a)
#
# NameError: name 'b' is not defined

# %% [markdown]
# ### Parameter c
# Der Parameter c verursacht eine Verschiebung in  𝑥−𝑅𝑖𝑐ℎ𝑡𝑢𝑛𝑔
#
# c > 0 : Verschiebung um c nach links
#
# c < 0 : Verschiebung um c nach rechts

# %%
x = np.arange(0,3*np.pi,0.1)   # start,stop,step
y = np.sin(x-1)
z = np.sin(x)
p = np.sin(x+1)

plt.plot(x,y,x,z,x,p)
plt.xlabel('x values from 0 to 2π')  # string must be enclosed with quotes '  '
plt.ylabel('sin(x-1), sin(x) and sin(x+1)')
plt.title('Plot of sin(x-1), sin(x) and sin(x+1) from 0 to 2π')
plt.legend(['sin(x-1)', 'sin(x)','sin(x+1)'])      # legend entries as seperate strings in a list
plt.show()

# %%
def plot_func(c):
   # x = np.linspace(0, 2*np.pi,)
    x = np.arange(0,3*np.pi,0.05)
    y = np.sin(x-c)
    z = np.sin(x)
    p = np.sin(x+c)
    
    plt.plot(x, y,x,z,x,p)
    plt.grid()
    plt.xlabel('x values from 0 to 2π')  # string must be enclosed with quotes '  '
    plt.ylabel('sin(x-c), sin(x) and sin(x+c)')
    plt.title('Plot of sin(x-c), sin(x) and sin(x+c) from 0 to 2π')
    plt.legend(['sin(x-c)', 'sin(x)','sin(x+c)'])      # legend entries as seperate strings in a list

interact(plot_func, c = widgets.FloatSlider(value=7.5,min=0.1, max=10.0, step=0.5))
# Out:
# interactive(children=(FloatSlider(value=7.5, description='c', max=10.0, min=0.1, step=0.5), Output()), _dom_cl…
# <function __main__.plot_func(c)>

# %% [markdown]
# ### Parameter d
# Der Parameter  𝑑  beeinflusst die Ruhelage. Er verschiebt den Graph in  𝑦−𝑅𝑖𝑐ℎ𝑡𝑢𝑛𝑔
#
# d > 0: Verschiebung um d nach oben
#
# d < 0: Verschiebung um d nach unten
#
# Der Graph hat die Ruhelage bei y = d

# %%
x = np.arange(0,3*np.pi,0.1)   # start,stop,step
y = np.sin(x)-1
z = np.sin(x)
p = np.sin(x)+2

plt.plot(x,y,x,z,x,p)
plt.xlabel('x values from 0 to 2π')  # string must be enclosed with quotes '  '
plt.ylabel('sin(x)-1, sin(x) and sin(x)+2')
plt.title('Plot of sin(x)-1, sin(x) and sin(x)+2 from 0 to 2π')
plt.legend(['sin(x)-1', 'sin(x)','sin(x)+2'])      # legend entries as seperate strings in a list
plt.show()

# %%
def plot_func(d):
   # x = np.linspace(0, 2*np.pi,)
    x = np.arange(0,3*np.pi,0.05)
    y = np.sin(x)-d
    z = np.sin(x)
    p = np.sin(x)+d
    
    plt.plot(x, y,x,z,x,p)
    plt.grid()
    plt.xlabel('x values from 0 to 2π')  # string must be enclosed with quotes '  '
    plt.ylabel('sin(x)-d, sin(x) and sin(x)+d')
    plt.title('Plot of sin(x)-d, sin(x) and sin(x)+d from 0 to 2π')
    plt.legend(['sin(x)-d', 'sin(x)','sin(x)+d'])      # legend entries as seperate strings in a list

interact(plot_func, d = widgets.FloatSlider(value=7.5,min=0.01, max=10.0, step=0.5))
# Out:
# interactive(children=(FloatSlider(value=7.5, description='d', max=10.0, min=0.01, step=0.5), Output()), _dom_c…
# <function __main__.plot_func(d)>

# %%
def plot_func(a,b,c,d):
   # x = np.linspace(0, 2*np.pi,)
    x = np.arange(-0,1*np.pi,0.05)
    y = np.sin(b*(x-c))*a-d
    z = np.sin(x)
    p = np.sin(b*(x+c))*a+d
    
    plt.plot(x, y,x,z,x,p)
    plt.grid()
    plt.xlabel('x values from 0 to 2π')  # string must be enclosed with quotes '  '
    plt.ylabel('a*sin(b(x-c)) - d, sin(x) and a*sin(b(x+c)) + d')
    plt.title('Plot of a*sin(b(x-c)) - d, sin(x) and a*sin(b(x+c)) + d from 0 to 2π')
    plt.legend(['a*sin(b(x-c)) - d', 'sin(x)','asin(b(x+c)) + d'])      # legend entries as seperate strings in a list

interact(plot_func, a = widgets.FloatSlider(value=7.5,min=0.1, max=10.0, step=0.5),
        b = widgets.FloatSlider(value=7.5,min=1, max=5.0, step=0.5),
        c = widgets.FloatSlider(value=7.5,min=1, max=5.0, step=1),
        d = widgets.FloatSlider(value=7.5,min=0.01, max=5.0, step=0.5),)
# Out:
# interactive(children=(FloatSlider(value=7.5, description='a', max=10.0, min=0.1, step=0.5), FloatSlider(value=…
# <function __main__.plot_func(a, b, c, d)>

# %% [markdown]
# ### Tangente Funktion

# %%
x = np.arange(0,2*np.pi,0.1)   # start,stop,step
y = np.tan(x)*3 -1
z = np.tan(x)
p = np.arctan(x-2)

plt.plot(x,y,x,z,x,p)
plt.xlabel('x values from 0 to 2π')  # string must be enclosed with quotes '  '
plt.ylabel('tan(x)*3 -1, tan(x) and arctan(x-2)')
plt.title('Plot of tan(x)*3 -1, tan(x) and arctan(x-2) from 0 to 2π')
plt.legend(['tan(x)*3 -1', 'tan(x)','arctan(x-2'])      # legend entries as seperate strings in a list
plt.show()

# %%
def plot_func(a,b,c,d):
   # x = np.linspace(0, 2*np.pi,)
    x = np.arange(0,1*np.pi,0.05)
    y = np.tan(b*(x-c))*a-d
    z = np.tan(x)
    p = np.arctan(b*(x+c))*a+d
    
    plt.plot(x, y,x,z,x,p)
    plt.grid()
    plt.xlabel('x values from 0 to 2π')  # string must be enclosed with quotes '  '
    plt.ylabel('a*tan(b(x-c)) - d, tan(x) and a*arctan(b(x+c)) + d')
    plt.title('Plot of a*tan(b(x-c)) - d, tan(x) and a*arctan(b(x+c)) + d from 0 to 2π')
    plt.legend(['a*tan(b(x-c)) - d', 'tan(x)','a*arctan(b(x+c)) + d'])      # legend entries as seperate strings in a list

interact(plot_func, a = widgets.FloatSlider(value=7.5,min=0.1, max=5.0, step=0.1),
        b = widgets.FloatSlider(value=7.5,min=0.1, max=1.0, step=0.1),
        c = widgets.FloatSlider(value=7.5,min=1.0, max=5.0, step=0.5),
        d = widgets.FloatSlider(value=7.5,min=0.01, max=30.0, step=0.5),)
# Out:
# interactive(children=(FloatSlider(value=5.0, description='a', max=5.0, min=0.1), FloatSlider(value=1.0, descri…
# <function __main__.plot_func(a, b, c, d)>

# %% [markdown]
# ### Sinus & Arc-sinus

# %%
x = np.arange(0,1*np.pi,0.05)   # start,stop,step
y = np.arcsin(x)
z = np.sin(x)


plt.plot(x,y,x,z)
plt.xlabel('x values from 0 to 2π')  # string must be enclosed with quotes '  '
plt.ylabel('arcsin(x) & sin(x)')
plt.title('Plot of arcsin(x) & sin(x) from 0 to 2π')
plt.legend(['arcsin(x)','sin(x)'])      # legend entries as seperate strings in a list
plt.show()
# Out:
# <ipython-input-26-068e132e347d>:2: RuntimeWarning: invalid value encountered in arcsin
#   y = np.arcsin(x)

# %% [markdown]
# ### Cosinus & Arc-Cosinus

# %%
x = np.arange(0,1*np.pi,0.05)   # start,stop,step
y = np.arccos(x)
z = np.cos(x)


plt.plot(x,y,x,z)
plt.xlabel('x values from 0 to 2π')  # string must be enclosed with quotes '  '
plt.ylabel('arccos(x) & cos(x)')
plt.title('Plot of arccos(x) & cos(x) from 0 to 2π')
plt.legend(['arccos(x)', 'cos(x)'])      # legend entries as seperate strings in a list
plt.show()
# Out:
# <ipython-input-27-f9d99a57c01d>:2: RuntimeWarning: invalid value encountered in arccos
#   y = np.arccos(x)

# %% [markdown]
# # References
#
#  ⋅ stackoverflow.com
#
#  ⋅ de.serlo.org
#
#  ⋅ hshl.de
#
#  ⋅
